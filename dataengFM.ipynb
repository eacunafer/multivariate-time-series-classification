# %% [markdown]
# ### Data engineering
# ### Dataset:Finger Movements
# ### Author: Edgar Acuna
# ### Created: March 22, 2025

# %%
# imports
import numpy as np
from numpy import mean
from numpy import std, unique
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

# %%
import pandas as pd
from aeon.datasets import load_classification
from sklearn import preprocessing

def load_data(dataset, split="Train"):
    if split=="Train":
        X, y= load_classification(dataset, split="Train")
    else:
        X, y= load_classification(dataset, split="Test")
    print(" Shape of X = ", X.shape)
    print(" Shape of y = ", y.shape)
    #Swap dimensions so features are the third dimension
    X = X.swapaxes(1, 2)
    print(" New shape of X = ", X.shape)
    #prepare y
    y = pd.DataFrame(y)
    enc = preprocessing.OneHotEncoder(dtype=int)
    enc.fit(y)
    y = enc.transform(y).toarray()
    print(" New shape of y = ", y.shape)
    return X, y

# %% [markdown]
# ### Training dataset

# %%
# loading the Training data
X, y = load_data("FingerMovements",split="Train")
# Out:
#  Shape of X =  (316, 28, 50)
#  Shape of y =  (316,)
#  New shape of X =  (316, 50, 28)
#  New shape of y =  (316, 2)

# %%
#class size in training 
import numpy as np
np.sum(y,axis=0)
# Out:
# array([159, 157])

# %%
#obtainiang the class labels
import numpy as np
yo=np.argmax(y,axis=1)
yo=np.array(yo,dtype=int)
#print(yo)

# %%
X1=X[yo==0]
X2=X[yo==1]

# %%
Xa1=X1.mean(axis=0).T
Xa1=pd.DataFrame(Xa1)
Xa2=X2.mean(axis=0).T
Xa2=pd.DataFrame(Xa2)
print(Xa2.shape)
# Out:
# (28, 50)

# %%
Xa=X.mean(axis=0).T
Xa=pd.DataFrame(Xa)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#fig, ax = plt.subplots(figsize=(20,10))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,8))
ejex=np.arange(0,50,1)
fig.suptitle("Fig. Plot of mean values by channel in each group;-FM training  dataset",fontsize=16)
ax1.plot(ejex, Xa1.iloc[0,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[1,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[2,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[3,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[4,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[5,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[6,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[7,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[8,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[9,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[10,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[11,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[12,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[13,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[14,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[15,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[16,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[17,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[18,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[19,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[20,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[21,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[22,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[23,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[24,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[25,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[26,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[27,ejex], color='black', lw=5, label='G1')
ax1.set_title("Group 1")
ax2.plot(ejex, Xa2.iloc[0,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[1,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[2,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[3,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[4,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[5,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[6,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa2.iloc[7,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[8,ejex], color='red', lw=5,label='G2')
ax2.plot(ejex, Xa2.iloc[9,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa2.iloc[10,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[11,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa1.iloc[12,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[13,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[14,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa2.iloc[15,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[16,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[17,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[18,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[19,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa2.iloc[20,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[21,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[22,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[23,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[24,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[25,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[26,ejex], color='red',lw=5, label='G2')
ax2.plot(ejex,Xa2.iloc[27,ejex], color='red', lw=5, label='G2')
ax2.set_title("Group 2")
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
fig, axs = plt.subplots(4, 7,figsize=(16,8))
axs[0,0].plot(ejex, Xa1.iloc[0,ejex], color='black',lw=3, label='G1')
fig.suptitle("Fig. Plot of mean values by channel in each group; G1(black),G2(red)-FM training  dataset",fontsize=16)
axs[0,0].plot(ejex, Xa1.iloc[0,ejex], color='black',lw=5, label='G1')
axs[0,0].plot(ejex, Xa2.iloc[0,ejex], color='red',lw=5,  label='G2')
axs[0,1].plot(ejex,Xa1.iloc[1,ejex], color='black', lw=5, label='G1')
axs[0,1].plot(ejex, Xa2.iloc[1,ejex], color='red', lw=5, label='G1')
axs[0,2].plot(ejex, Xa1.iloc[2,ejex], color='black',lw=5, label='G1')
axs[0,2].plot(ejex,Xa2.iloc[2,ejex], color='red', lw=5, label='G1')
axs[0,3].plot(ejex, Xa1.iloc[3,ejex], color='black', lw=5,  label='G1')
axs[0,3].plot(ejex, Xa2.iloc[3,ejex], color='red',lw=5,  label='G1')
axs[0,4].plot(ejex,Xa1.iloc[4,ejex], color='black', lw=5, label='G1')
axs[0,4].plot(ejex, Xa2.iloc[4,ejex], color='red', lw=5,  label='G1')
axs[0,5].plot(ejex, Xa1.iloc[5,ejex], color='black',lw=5,  label='G1')
axs[0,5].plot(ejex,Xa2.iloc[5,ejex], color='red', lw=5, label='G1')
axs[0,6].plot(ejex, Xa1.iloc[6,ejex], color='black',lw=5,  label='G2')
axs[0,6].plot(ejex, Xa2.iloc[6,ejex], color='red',lw=5,  label='G2')
axs[1,0].plot(ejex,Xa1.iloc[7,ejex], color='black', lw=5, label='G1')
axs[1,0].plot(ejex, Xa2.iloc[7,ejex], color='red', lw=5, label='G1')
axs[1,1].plot(ejex, Xa1.iloc[8,ejex], color='black',lw=5, label='G1')
axs[1,1].plot(ejex,Xa2.iloc[8,ejex], color='red', lw=5, label='G1')
axs[1,2].plot(ejex, Xa1.iloc[9,ejex], color='black',lw=5, label='G1')
axs[1,2].plot(ejex,Xa2.iloc[9,ejex], color='red', lw=5, label='G1')
axs[1,3].plot(ejex, Xa1.iloc[10,ejex], color='black', lw=5,  label='G1')
axs[1,3].plot(ejex, Xa2.iloc[10,ejex], color='red',lw=5, label='G1')
axs[1,4].plot(ejex,Xa1.iloc[11,ejex], color='black', lw=5, label='G1')
axs[1,4].plot(ejex, Xa2.iloc[11,ejex], color='red',lw=5, label='G1')
axs[1,5].plot(ejex,Xa1.iloc[12,ejex], color='black', lw=5, label='G1')
axs[1,5].plot(ejex, Xa2.iloc[12,ejex], color='red',lw=5, label='G1')
axs[1,6].plot(ejex,Xa1.iloc[13,ejex], color='black', lw=5, label='G1')
axs[1,6].plot(ejex, Xa2.iloc[13,ejex], color='red', lw=5,  label='G1')
axs[2,0].plot(ejex, Xa1.iloc[14,ejex], color='black',lw=5, label='G1')
axs[2,0].plot(ejex, Xa2.iloc[14,ejex], color='red',lw=5,  label='G2')
axs[2,1].plot(ejex,Xa1.iloc[15,ejex], color='black', lw=5, label='G1')
axs[2,1].plot(ejex, Xa2.iloc[15,ejex], color='red', lw=5, label='G1')
axs[2,2].plot(ejex, Xa1.iloc[16,ejex], color='black',lw=5, label='G1')
axs[2,2].plot(ejex,Xa2.iloc[16,ejex], color='red', lw=5, label='G1')
axs[2,3].plot(ejex, Xa1.iloc[17,ejex], color='black', lw=5,  label='G1')
axs[2,3].plot(ejex, Xa2.iloc[17,ejex], color='red',lw=5,  label='G1')
axs[2,4].plot(ejex,Xa1.iloc[18,ejex], color='black', lw=5, label='G1')
axs[2,4].plot(ejex, Xa2.iloc[18,ejex], color='red', lw=5,  label='G1')
axs[2,5].plot(ejex, Xa1.iloc[19,ejex], color='black',lw=5,  label='G1')
axs[2,5].plot(ejex,Xa2.iloc[19,ejex], color='red', lw=5, label='G1')
axs[2,6].plot(ejex, Xa1.iloc[20,ejex], color='black',lw=5,  label='G2')
axs[2,6].plot(ejex, Xa2.iloc[20,ejex], color='red',lw=5,  label='G2')
axs[3,0].plot(ejex,Xa1.iloc[21,ejex], color='black', lw=5, label='G1')
axs[3,0].plot(ejex, Xa2.iloc[21,ejex], color='red', lw=5, label='G1')
axs[3,1].plot(ejex, Xa1.iloc[22,ejex], color='black',lw=5, label='G1')
axs[3,1].plot(ejex,Xa2.iloc[22,ejex], color='red', lw=5, label='G1')
axs[3,2].plot(ejex, Xa1.iloc[23,ejex], color='black',lw=5, label='G1')
axs[3,2].plot(ejex,Xa2.iloc[23,ejex], color='red', lw=5, label='G1')
axs[3,3].plot(ejex, Xa1.iloc[24,ejex], color='black', lw=5,  label='G1')
axs[3,3].plot(ejex, Xa2.iloc[24,ejex], color='red',lw=5, label='G1')
axs[3,4].plot(ejex,Xa1.iloc[25,ejex], color='black', lw=5, label='G1')
axs[3,4].plot(ejex, Xa2.iloc[25,ejex], color='red',lw=5, label='G1')
axs[3,5].plot(ejex,Xa1.iloc[26,ejex], color='black', lw=5, label='G1')
axs[3,5].plot(ejex, Xa2.iloc[26,ejex], color='red',lw=5, label='G1')
axs[3,6].plot(ejex,Xa1.iloc[27,ejex], color='black', lw=5, label='G1')
axs[3,6].plot(ejex, Xa2.iloc[27,ejex], color='red', lw=5,  label='G1')
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
X.var(axis=0).sum()/(50*28)
# Out:
# 946.5813890825646

# %%
#Boxplots of the dimensions in the training dataset
tempotr=X.reshape(X.shape[2],-1).T
tempodftr=pd.DataFrame(tempotr)
print(tempodftr.shape)
pyplot.boxplot(tempodftr)
pyplot.show()
# Out:
# (15800, 28)

# %%
#Boxplots of each dimensiom in the groups of the training dataset
temptr=pd.DataFrame(tempotr)
from itertools import cycle
variables= cycle(yo)
print(variables)
temptr['group'] = [next(variables) for variable in range(len(temptr))]
#Bboxplot  of features by class
temptr.boxplot(by='group')
# Out:
# ...
# array([[<Axes: title={'center': '0'}, xlabel='[group]'>,
#         <Axes: title={'center': '1'}, xlabel='[group]'>,
#         <Axes: title={'center': '2'}, xlabel='[group]'>,
#         <Axes: title={'center': '3'}, xlabel='[group]'>,
#         <Axes: title={'center': '4'}, xlabel='[group]'>],
#        [<Axes: title={'center': '5'}, xlabel='[group]'>,
#         <Axes: title={'center': '6'}, xlabel='[group]'>,
#         <Axes: title={'center': '7'}, xlabel='[group]'>,
#         <Axes: title={'center': '8'}, xlabel='[group]'>,
#         <Axes: title={'center': '9'}, xlabel='[group]'>],
#        [<Axes: title={'center': '10'}, xlabel='[group]'>,
#         <Axes: title={'center': '11'}, xlabel='[group]'>,
#         <Axes: title={'center': '12'}, xlabel='[group]'>,
#         <Axes: title={'center': '13'}, xlabel='[group]'>,
#         <Axes: title={'center': '14'}, xlabel='[group]'>],
#        [<Axes: title={'center': '15'}, xlabel='[group]'>,
# ...

# %%
#Statistical measures of each dimension
tempodftr.describe()
# Out:
#                  0             1             2             3             4   \
# count  15800.000000  15800.000000  15800.000000  15800.000000  15800.000000
# mean      34.558949     38.374570     14.625266     23.599373     24.100690
# std       40.089358     41.733902     47.905764     46.510255     42.782867
# min      -70.200000    -63.700000   -116.100000   -132.100000    -75.500000
# 25%        7.500000      8.600000    -22.200000     -3.500000     -9.000000
# 50%       29.800000     34.900000     12.800000     21.400000     20.000000
# 75%       59.000000     64.500000     46.600000     52.700000     50.900000
# max      167.000000    171.700000    181.200000    162.100000    188.800000
#
#                  5             6             7             8             9   \
# count  15800.000000  15800.000000  15800.000000  15800.000000  15800.000000
# mean      33.490203     34.766924     33.131424     33.623253     38.249019
# ...

# %%
#Variance on each time step
tempoA=X.reshape(X.shape[1],-1).T
print(tempoA.shape)
tempoA1=pd.DataFrame(tempoA)
tempoA1.var()
# Out:
# (8848, 50)
# 0     1620.622590
# 1     1595.151334
# 2     1661.077526
# 3     2242.840828
# 4     2423.024938
# 5     1762.044138
# 6     2704.139558
# 7     1850.323091
# 8     1768.766815
# 9     2010.562590
# 10    1281.377575
# 11    1375.382898
# 12    1638.999305
# 13    1570.936713
# 14    1727.961965
# 15    1697.111712
# 16    1487.803015
# 17    2145.885239
# 18    3167.249760
# 19    1549.316009
# 20    2403.205355
# 21    1537.454861
# 22    1528.017586
# 23    1616.023556
# 24    2040.563672
# 25    2720.999019
# 26    1682.438479
# 27    2018.259900
# 28    2071.096089
# 29    2022.026718
# 30    2143.538997
# 31    2397.726247
# 32    1472.750415
# 33    1708.165189
# 34    1428.092971
# 35    1920.469034
# 36    1432.791248
# 37    1460.080268
# 38    1488.127723
# 39    1490.561932
# 40    1531.424071
# 41    1965.009854
# 42    2482.709843
# 43    2124.632235
# 44    1768.634049
# 45    1424.280613
# 46    1642.813696
# 47    2213.832048
# 48    2229.617949
# ...

# %% [markdown]
# ###  Distances

# %%
#Distance between the features in the two groups of the treining
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([1.64029354])

# %%
#media total training
meanTr=tempoA.mean(axis=0)
meanTr.shape
# Out:
# (50,)

# %%
tempoB=pd.DataFrame(tempoA)
from itertools import cycle
variables= cycle(yo)
print(variables)
tempoB['group'] = [next(variables) for variable in range(len(tempoB))]
#Bboxplot  of features by class
a=tempoB.groupby('group').mean()

# %% [markdown]
# ### Feature selection

# %%
#Feature selection
from sklearn.feature_selection import  mutual_info_classif, SelectPercentile, f_classif
ym=tempoB['group']
Xm=tempoB.iloc[:,0:50]
scores = mutual_info_classif(Xm,ym)
scores /= scores.max()
importance=[i for i,v in enumerate(scores) if v > .5]
len(importance)*100/50
# Out:
# 20.0

# %%
selector = SelectPercentile(f_classif, percentile=30)
Xm_new=selector.fit_transform(Xm, ym)
scores = -np.log10(selector.pvalues_)
#scores /= scores.max()
#print(scores)
#critical p-value=.15
importance=[i for i,v in enumerate(scores) if v > 0.8239]
len(importance)*100/50
# Out:
# 0.0

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=2500)
Xv_new=selector.fit_transform(Xm)
Xv_new.shape
# Out:
# (8848, 3)

# %%
temptr.groupby('group').mean()
# Out:
#               0          1          2          3          4          5   \
# group
# 0      34.426465  38.300428  14.458013  23.383245  23.819937  33.546138
# 1      34.693121  38.449656  14.794650  23.818255  24.385019  33.433554
#
#               6          7          8          9   ...         18         19  \
# group                                              ...
# 0      34.472025  33.104302  33.697824  38.132566  ...  24.708289  32.684403
# 1      35.065580  33.158892  33.547732  38.366955  ...  25.154433  32.885707
#
#               20         21         22         23         24         25  \
# group
# 0      25.197799  37.017434  35.001132  36.069962  38.933874  39.614994
# 1      25.383745  37.147159  34.775975  36.117389  39.428637  39.661669
#
#               26         27
# group
# 0      19.804214  31.195258
# 1      20.140089  31.601070
#
# [2 rows x 28 columns]

# %%
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([1.64029354])

# %% [markdown]
# ### Testing dataset

# %%
# loading Testing data
Xt, yt = load_data("FingerMovements",split="Test")
# Out:
#  Shape of X =  (100, 28, 50)
#  Shape of y =  (100,)
#  New shape of X =  (100, 50, 28)
#  New shape of y =  (100, 2)

# %%
#class size in testing
import numpy as np
np.sum(yt,axis=0)
# Out:
# array([49, 51])

# %%
ar=np.sum(yt,axis=0)
np.max(ar/Xt.shape[0])
# Out:
# 0.51

# %%
yto=np.argmax(yt,axis=1)
yto=np.array(yto,dtype=int)
#print(yto)

# %%
Xta=Xt.mean(axis=0).T
Xta=pd.DataFrame(Xta)

# %%
tempote=Xt.reshape(Xt.shape[2],-1).T
tempodfte=pd.DataFrame(tempote)
print(tempodfte.shape)
pyplot.boxplot(tempodfte)
pyplot.show()
# Out:
# (5000, 28)

# %%
tempodfte.describe()
# Out:
#                 0            1            2            3            4   \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     32.457300    34.397840    30.600580    12.046840    31.209820
# std      46.769771    41.123117    42.634605    38.028253    40.753295
# min     -75.700000   -65.700000   -57.800000   -65.700000   -71.200000
# 25%       6.475000     4.300000    -0.900000   -18.725000     2.900000
# 50%      31.100000    30.900000    26.800000     8.400000    27.550000
# 75%      62.925000    57.425000    57.200000    34.125000    56.225000
# max     186.400000   186.400000   176.300000   134.300000   167.400000
#
#                 5            6            7            8            9   ...  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean     32.472100    42.863560    41.049920     9.556080    23.337120  ...
# std      34.317649    55.161166    37.251351    39.120415    37.255314  ...
# ...

# %%
tempoA=Xt.reshape(Xt.shape[1],-1).T
print(tempoA.shape)
tempoA1=pd.DataFrame(tempoA)
tempoA1.var()
# Out:
# (2800, 50)
# 0     2634.134373
# 1     1352.852800
# 2     1532.143113
# 3     1448.165190
# 4     1870.389380
# 5     1480.299186
# 6     1334.832311
# 7     1316.289793
# 8     2005.619995
# 9     1047.944704
# 10    1117.592286
# 11    2625.798344
# 12    1534.745183
# 13    1317.715287
# 14    1579.667995
# 15    1469.749767
# 16    1347.186232
# 17    1410.327176
# 18    1474.342185
# 19    1515.165346
# 20    1281.857446
# 21    1239.873364
# 22    1826.913957
# 23    1390.678686
# 24    2838.608422
# 25    2202.358480
# 26    1220.378944
# 27    1878.141495
# 28    1547.306754
# 29    1300.260614
# 30    2027.866141
# 31    1311.271842
# 32    1777.585917
# 33    1537.041422
# 34    1303.659646
# 35    1389.081625
# 36    1142.427976
# 37    1341.396919
# 38    1678.062240
# 39    1546.927009
# 40    1696.992087
# 41    1551.583729
# 42    1957.168229
# 43    2009.257329
# 44    1435.681690
# 45    1584.097245
# 46    1279.726774
# 47    1955.225572
# 48    1375.037099
# ...

# %%
tempoB1=pd.DataFrame(tempoA1)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempoB1['group'] = [next(variables) for variable in range(len(tempoB1))]
#Bboxplot  of features by class
a1=tempoB1.groupby('group').mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, (ax1,ax2) = plt.subplots(2,figsize=(20,10))
ejex=np.arange(0,50,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-FM training dataset",fontsize=16)
ax1.plot(ejex, a.iloc[0,ejex], color='red',lw=5, label='G1')
ax1.plot(ejex,a.iloc[1,ejex], color='blue', lw=5, label='G2')
ax1.legend(loc='best', frameon=False)
ax2.plot(ejex, a1.iloc[0,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,a1.iloc[1,ejex], color='blue', lw=5, label='G2')
ax2.legend(loc='best', frameon=False)
plt.show()

# %%
#media total testung
meanTe=tempoA1.mean(axis=0)
meanTe.shape
# Out:
# (50,)

# %% [markdown]
# ### Distance between training and Testing

# %%
#Distance Training and Testsing
from scipy.spatial import distance
dst = distance.euclidean(meanTr, meanTe)
dst
# Out:
# 145.2678934031175

# %% [markdown]
# ### Stationarity

# %%
#Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
Xest = tempoB.iloc[10,0:50]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.368579
# p-value: 0.000000
# Critical Values:
# 	1%: -3.571
# 	5%: -2.923
# 	10%: -2.599

# %%
sm.graphics.tsa.plot_acf(Xest, alpha=.05)

# %%
Xest = tempoB.iloc[20,0:50]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.840086
# p-value: 0.000000
# Critical Values:
# 	1%: -3.571
# 	5%: -2.923
# 	10%: -2.599
