# %% [markdown]
# ### Data Enfineering
# ### Dataset:Heartbeat
# ### Author: Edgar Acuna
# ### Created: March 22, 2025

# %%
# imports
import numpy as np
from numpy import mean
from numpy import std, unique
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

# %%
import pandas as pd
from aeon.datasets import load_classification
from sklearn import preprocessing

def load_data(dataset, split="Train"):
    if split=="Train":
        X, y= load_classification(dataset, split="Train")
    else:
        X, y= load_classification(dataset, split="Test")
    print(" Shape of X = ", X.shape)
    print(" Shape of y = ", y.shape)
    #Swap dimensions so features are the third dimension
    X = X.swapaxes(1, 2)
    print(" New shape of X = ", X.shape)
    #prepare y
    y = pd.DataFrame(y)
    enc = preprocessing.OneHotEncoder(dtype=int)
    enc.fit(y)
    y = enc.transform(y).toarray()
    print(" New shape of y = ", y.shape)
    return X, y

# %%
# loading Training data
X, y = load_data("Heartbeat",split="Train")
# Out:
#  Shape of X =  (204, 61, 405)
#  Shape of y =  (204,)
#  New shape of X =  (204, 405, 61)
#  New shape of y =  (204, 2)

# %%
import numpy as np
yo=np.argmax(y,axis=1)
yo=np.array(yo,dtype=int)
#print(yo)

# %%
#class size in training
import numpy as np
np.sum(y,axis=0)
# Out:
# array([147,  57])

# %%
X1=X[yo==0]
X2=X[yo==1]

# %%
Xa1=X1.mean(axis=0).T
Xa1=pd.DataFrame(Xa1)
Xa2=X2.mean(axis=0).T
Xa2=pd.DataFrame(Xa2)
print(Xa2.shape)
# Out:
# (61, 405)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,405,15)
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,8))
#fig, ax = plt.subplots(figsize=(20,10))
fig.suptitle("Fig. Plot of mean values by channel in each group-HB training dataset",fontsize=16)
ax1.plot(ejex, Xa1.iloc[0,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[1,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[2,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[3,ejex], color='black',lw=5, label='G2')
ax1.plot(ejex,Xa1.iloc[4,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[5,ejex], color='black', lw=5,  label='G2')
ax1.plot(ejex, Xa1.iloc[6,ejex], color='black',lw=5,  label='G3')
ax1.plot(ejex,Xa1.iloc[7,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[8,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[9,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[10,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[11,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[12,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[13,ejex], color='black', lw=5, label='G3')
ax1.plot(ejex, Xa1.iloc[14,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[15,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[16,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[17,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[18,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[19,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[20,ejex], color='black', lw=5, label='G4')
ax1.plot(ejex, Xa1.iloc[21,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[22,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[23,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[24,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[25,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[26,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[27,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[28,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[29,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[30,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[31,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[32,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[33,ejex], color='black', lw=5, label='G3')
ax1.plot(ejex, Xa1.iloc[34,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[35,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[36,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[37,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[38,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[39,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[40,ejex], color='black', lw=5, label='G4')
ax1.plot(ejex, Xa1.iloc[41,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[42,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[43,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[44,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[45,ejex], color='black', lw=5,  label='G1')
ax1.plot(ejex, Xa1.iloc[46,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[47,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[48,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[49,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[50,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[51,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[52,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[53,ejex], color='black', lw=5, label='G3')
ax1.plot(ejex, Xa1.iloc[54,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[55,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[56,ejex], color='black',lw=5, label='G1')
ax1.plot(ejex,Xa1.iloc[57,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[58,ejex], color='black', lw=5, label='G1')
ax1.plot(ejex, Xa1.iloc[59,ejex], color='black',lw=5,  label='G1')
ax1.plot(ejex,Xa1.iloc[60,ejex], color='black', lw=5, label='G4')
ax1.set_title("Group 1")
ax2.plot(ejex, Xa2.iloc[0,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[1,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[2,ejex], color='red', lw=5,  label='G1')
ax2.plot(ejex, Xa2.iloc[3,ejex], color='red',lw=5,  label='G2')
ax2.plot(ejex,Xa2.iloc[4,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[5,ejex], color='red', lw=5, label='G2')
ax2.plot(ejex, Xa2.iloc[6,ejex], color='red',lw=5, label='G3')
ax2.plot(ejex,Xa2.iloc[7,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[8,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[9,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[10,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[11,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa1.iloc[12,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[13,ejex], color='red', lw=5, label='G3')
ax2.plot(ejex, Xa2.iloc[14,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[15,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[16,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[17,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[18,ejex], color='red', lw=5,  label='G1')
ax2.plot(ejex, Xa2.iloc[19,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[20,ejex], color='red', lw=5, label='G4')
ax2.plot(ejex, Xa2.iloc[21,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[22,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[23,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[24,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[25,ejex], color='red', lw=5,label='G1')
ax2.plot(ejex, Xa2.iloc[26,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[27,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[28,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[29,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[30,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[31,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[32,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[33,ejex], color='red', lw=5,  label='G3')
ax2.plot(ejex, Xa2.iloc[34,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[35,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[36,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[37,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[38,ejex], color='red', lw=5,label='G1')
ax2.plot(ejex, Xa2.iloc[39,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[40,ejex], color='red', lw=5, label='G4')
ax2.plot(ejex, Xa2.iloc[41,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[42,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[43,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[44,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[45,ejex], color='red', lw=5,  label='G1')
ax2.plot(ejex, Xa2.iloc[46,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[47,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[48,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[49,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[50,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[51,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa1.iloc[52,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[53,ejex], color='red', lw=5, label='G3')
ax2.plot(ejex, Xa2.iloc[54,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[55,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[56,ejex], color='red',lw=5,  label='G1')
ax2.plot(ejex,Xa2.iloc[57,ejex], color='red', lw=5, label='G1')
ax2.plot(ejex, Xa2.iloc[58,ejex], color='red', lw=5,  label='G1')
ax2.plot(ejex, Xa2.iloc[59,ejex], color='red',lw=5, label='G1')
ax2.plot(ejex,Xa2.iloc[60,ejex], color='red', lw=5, label='G4')
ax2.set_title("Group 2")
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
# loading Testing data
Xt, yt = load_data("Heartbeat",split="Test")
# Out:
#  Shape of X =  (205, 61, 405)
#  Shape of y =  (205,)
#  New shape of X =  (205, 405, 61)
#  New shape of y =  (205, 2)

# %%
#class size in testing
import numpy as np
np.sum(yt,axis=0)
# Out:
# array([148,  57])

# %%
a=np.sum(yt,axis=0)
np.max(a/Xt.shape[0])
# Out:
# 0.7219512195121951

# %%
tempotr=X.reshape(X.shape[2],-1).T
tempotr=pd.DataFrame(tempotr)

# %%
#Boxplots of each feature inthe groups pf the training dataset
temptr=pd.DataFrame(tempotr)
from itertools import cycle
variables= cycle(yo)
print(variables)
temptr['group'] = [next(variables) for variable in range(len(temptr))]
#Bboxplot  of features by class
#temptr.boxplot(by='group')
temptr.groupby('group').mean()
# Out:
# ...
#             0        1         2         3         4         5         6   \
# group
# 0      0.05028  0.14563  0.089027  0.096860  0.099516  0.103134  0.112823
# 1      0.05095  0.14313  0.087676  0.094064  0.099195  0.103705  0.114014
#
#              7         8         9   ...        51        52        53  \
# group                                ...
# 0      0.074258  0.138318  0.081392  ...  0.056025  0.087803  0.050790
# 1      0.076619  0.138395  0.079056  ...  0.055079  0.090444  0.052308
#
#              54        55        56        57        58        59        60
# group
# 0      0.067334  0.063337  0.080196  0.044917  0.036437  0.049336  0.046949
# 1      0.066561  0.067006  0.080107  0.046698  0.036365  0.049322  0.047344
#
# [2 rows x 61 columns]

# %% [markdown]
# ### Distances

# %%
#Distance between the features in the two groups of the treining
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.01867852])

# %%
tempoA=X.reshape(X.shape[1],-1).T
print(tempoA.shape)
# Out:
# (12444, 405)

# %%
#media total training
meanTr=tempoA.mean(axis=0)
meanTr.shape
# Out:
# (405,)

# %%
tempoB=pd.DataFrame(tempoA)
from itertools import cycle
variables= cycle(yo)
print(variables)
tempoB['group'] = [next(variables) for variable in range(len(tempoB))]
#Bboxplot  of features by class
a=tempoB.groupby('group').mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,405,15)
fig.suptitle("Fig. Plot of mean values by group-HB training dataset",fontsize=16)
ax.plot(ejex, a.iloc[0,ejex], color='red',lw=5, label='G1')
ax.plot(ejex,a.iloc[1,ejex], color='blue', lw=5, label='G2')
ax.legend(loc='best', frameon=False)

# %% [markdown]
# ### Feature selection

# %%
#Feature selection
from sklearn.feature_selection import  mutual_info_classif, SelectPercentile, f_classif
ym=tempoB['group']
Xm=tempoB.iloc[:,0:405]
scores = mutual_info_classif(Xm,ym)
scores /= scores.max()
importance=[i for i,v in enumerate(scores) if v > .5]
len(importance)*100/405
# Out:
# 10.864197530864198

# %%
selector = SelectPercentile(f_classif, percentile=30)
Xm_new=selector.fit_transform(Xm, ym)
scores = -np.log10(selector.pvalues_)
#scores /= scores.max()
#print(scores)
#critical p-value.15
importance=[i for i,v in enumerate(scores) if v > .8239]
len(importance)*100/405
# Out:
# 2.2222222222222223

# %%
ym=tempoB['group']
Xm=tempoB.iloc[:,0:405]
#scores = mutual_info_classif(Xm,ym)
#scores /= scores.max()
#importance=[i for i,v in enumerate(scores) if v > .5]
#len(importance)*100/206
selector = SelectPercentile(f_classif, percentile=30)
Xm_new=selector.fit_transform(Xm, ym)
scores = -np.log10(selector.pvalues_)
#scores /= scores.max()
#print(scores)
importance=[i for i,v in enumerate(scores) if v > .698]
len(importance)*100/405
# Out:
# 4.197530864197531

# %%
yto=np.argmax(yt,axis=1)
yto=np.array(yto,dtype=int)
#print(yto)

# %%
#Boxplot of features in the testing dataset
tempote=Xt.reshape(Xt.shape[2],-1).T
tempodfte=pd.DataFrame(tempote)
print(tempodfte.shape)
#pyplot.boxplot(tempodfte)
#pyplot.show()
# Out:
# (83025, 61)

# %%
#Boxplors of features in each group of the testing dataset
tempte=pd.DataFrame(tempote)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempte['group'] = [next(variables) for variable in range(len(tempte))]
#Boxplot  of features by class in testing
#tempte.boxplot(by='group')

# %%
means1=tempte.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances1 = pdist(means1, metric='euclidean')
distances1
# Out:
# array([0.01433077])

# %%
Xt1=Xt[yto==0]
Xt2=Xt[yto==1]

# %%
Xta1=Xt1.mean(axis=0).T
Xta1=pd.DataFrame(Xta1)
Xta2=Xt2.mean(axis=0).T
Xta2=pd.DataFrame(Xta2)
print(Xta2.shape)
# Out:
# (61, 405)

# %%
import numpy as np
Xb= np.concatenate((X, Xt),axis=0)
tempo1=Xb.reshape(Xb.shape[2],-1).T
print(Xb.shape)
tempodf1=pd.DataFrame(tempo1)
print(tempodf1.shape)
#pyplot.boxplot(tempodf1)
#pyplot.show()
# Out:
# (409, 405, 61)
# (165645, 61)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,405,15)
fig.suptitle("Fig. Plot of mean values by dimension en each group-HB testing dataset",fontsize=16)
ax.plot(ejex, Xta1.iloc[0,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[1,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[2,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[3,ejex], color='black',lw=3, alpha=0.5, label='G2')
ax.plot(ejex,Xta1.iloc[4,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[5,ejex], color='black', lw=3, alpha=0.5, label='G2')
ax.plot(ejex, Xta1.iloc[6,ejex], color='black',lw=3, alpha=0.5, label='G3')
ax.plot(ejex,Xta1.iloc[7,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[8,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[9,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[10,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xa1.iloc[11,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[12,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[13,ejex], color='black', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta1.iloc[14,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[15,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[16,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[17,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[18,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[19,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[20,ejex], color='black', lw=3, label='G4')
ax.plot(ejex, Xta1.iloc[21,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[22,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[23,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[24,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[25,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[26,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[27,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[28,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[29,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[30,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[31,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[32,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[33,ejex], color='black', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta1.iloc[34,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[35,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[36,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[37,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[38,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[39,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[40,ejex], color='black', lw=3, label='G4')
ax.plot(ejex, Xta1.iloc[41,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[42,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[43,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[44,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[45,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[46,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[47,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[48,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta1.iloc[49,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[50,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[51,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[52,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[53,ejex], color='black', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta1.iloc[54,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[55,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[56,ejex], color='black',lw=3, label='G1')
ax.plot(ejex,Xta1.iloc[57,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[58,ejex], color='black', lw=3, label='G1')
ax.plot(ejex, Xta1.iloc[59,ejex], color='black',lw=3,  label='G1')
ax.plot(ejex,Xta1.iloc[60,ejex], color='black', lw=3, label='G4')
ax.plot(ejex, Xta2.iloc[0,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[1,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[2,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[3,ejex], color='red',lw=3, alpha=0.5, label='G2')
ax.plot(ejex,Xta2.iloc[4,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[5,ejex], color='red', lw=3, alpha=0.5, label='G2')
ax.plot(ejex, Xta2.iloc[6,ejex], color='red',lw=3, alpha=0.5, label='G3')
ax.plot(ejex,Xta2.iloc[7,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[8,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[9,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[10,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[11,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[12,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[13,ejex], color='red', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta2.iloc[14,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[15,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[16,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[17,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[18,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[19,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[20,ejex], color='red', lw=3, label='G4')
ax.plot(ejex, Xta2.iloc[21,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[22,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[23,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[24,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[25,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[26,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[27,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[28,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[29,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[30,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[31,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta1.iloc[32,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[33,ejex], color='red', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta2.iloc[34,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[35,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[36,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[37,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[38,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[39,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[40,ejex], color='red', lw=3, label='G4')
ax.plot(ejex, Xta2.iloc[41,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[42,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[43,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[44,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[45,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[46,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[47,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[48,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[49,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[50,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[51,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[52,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[53,ejex], color='red', lw=3, alpha=0.5, label='G3')
ax.plot(ejex, Xta2.iloc[54,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[55,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xa2.iloc[56,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[57,ejex], color='red', lw=3, label='G1')
ax.plot(ejex, Xta2.iloc[58,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta2.iloc[59,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta2.iloc[60,ejex], color='red', lw=3, label='G4')
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
tempoA1=Xt.reshape(Xt.shape[1],-1).T
print(tempoA1.shape)
# Out:
# (12505, 405)

# %%
tempoB1=pd.DataFrame(tempoA1)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempoB1['group'] = [next(variables) for variable in range(len(tempoB1))]
#Bboxplot  of features by class
a1=tempoB1.groupby('group').mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, (ax1,ax2) = plt.subplots(2,figsize=(20,10))
ejex=np.arange(0,405,15)
fig.suptitle("Fig. Plot of mean values by group-HB training dataset(above) testing dataset (below) ",fontsize=16)
ax1.plot(ejex, a.iloc[0,ejex], color='red',lw=5, label='G1')
ax1.plot(ejex,a.iloc[1,ejex], color='blue', lw=5, label='G2')
ax1.legend(loc='best', frameon=False)
ax2.plot(ejex, a1.iloc[0,ejex], color='red',lw=3, label='G1')
ax2.plot(ejex,a1.iloc[1,ejex], color='blue', lw=3, label='G2')
ax2.legend(loc='best', frameon=False)
plt.show()

# %%
#media total testung
meanTe=tempoA1.mean(axis=0)
meanTe.shape
# Out:
# (405,)

# %%
#Distance Training and Testsing
from scipy.spatial import distance
dst = distance.euclidean(meanTr, meanTe)
dst
# Out:
# 3.4586914924490015

# %%
#Distance between the features in the two groups of the treining
means=tempte.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.01433077])

# %% [markdown]
# ### Stationarity

# %%
#Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
Xest = tempoB.iloc[50,0:405]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -14.674370
# p-value: 0.000000
# Critical Values:
# 	1%: -3.447
# 	5%: -2.869
# 	10%: -2.571

# %%
sm.graphics.tsa.plot_acf(Xest, alpha=.05)

# %%
Xest = tempoB.iloc[100,0:405]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -16.508182
# p-value: 0.000000
# Critical Values:
# 	1%: -3.447
# 	5%: -2.869
# 	10%: -2.571
