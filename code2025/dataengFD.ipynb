# %% [markdown]
# ### Data engineering
# ### Dataset: Face Detection
# ### Author: Edgar Acuna
# ### Created: March 24, 2025

# %%
# cnn lstm model
from numpy import mean
from numpy import std, unique
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

# %%
import pandas as pd
from aeon.datasets import load_classification
from sklearn import preprocessing

import pandas as pd
from aeon.datasets import load_classification
from sklearn import preprocessing

def load_data(dataset, split="Train"):
    if split=="Train":
        X, y= load_classification(dataset, split="Train")
    else:
        X, y= load_classification(dataset, split="Test")
    print(" Shape of X = ", X.shape)
    print(" Shape of y = ", y.shape)
    #Swap dimensions so features are the third dimension
    X = X.swapaxes(1, 2)
    print(" New shape of X = ", X.shape)
    #prepare y
    y = pd.DataFrame(y)
    enc = preprocessing.OneHotEncoder(dtype=int)
    enc.fit(y)
    y = enc.transform(y).toarray()
    print(" New shape of y = ", y.shape)
    return X, y

# %%
# loading Training data
X, y = load_data("FaceDetection",split="Train")
# Out:
#  Shape of X =  (5890, 144, 62)
#  Shape of y =  (5890,)
#  New shape of X =  (5890, 62, 144)
#  New shape of y =  (5890, 2)

# %%
#class size in training 
import numpy as np
np.sum(y,axis=0)
# Out:
# array([2945, 2945])

# %%
import numpy as np
yo=np.argmax(y,axis=1)
yo=np.array(yo,dtype=int)
#print(yo)

# %%
Xa=X.mean(axis=0).T
Xa=pd.DataFrame(Xa)

# %%
Xa.shape
# Out:
# (144, 62)

# %%
#Extracting the time series by class
X1=X[yo==0]
X2=X[yo==1]
print(X2.shape)
# Out:
# (2945, 62, 144)

# %%
#Calculating the means of the dimensions in each group
Xa1=X1.mean(axis=0).T
Xa1=pd.DataFrame(Xa1)

Xa2=X2.mean(axis=0).T
Xa2=pd.DataFrame(Xa2)
print(Xa2.shape)
# Out:
# (144, 62)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=range(0,62,1)
fig.suptitle("Fig. Plot of mean values of the first 20 channels by group, G1(black) G2(blue)-FD training dataset",fontsize=16)
ax.plot(ejex, Xa1.iloc[0,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[1,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[2,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[3,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[4,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[5,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[6,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[7,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[8,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[9,ejex], color='black',lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[10,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[11,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[12,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[13,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[14,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[15,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[16,ejex], color='black',lw=5, label='G1')
ax.plot(ejex,Xa1.iloc[17,ejex], color='black', lw=5,  label='G1')
ax.plot(ejex, Xa1.iloc[18,ejex], color='black', lw=5, label='G1')
ax.plot(ejex, Xa1.iloc[19,ejex], color='black',lw=5, label='G1')
ax.plot(ejex, Xa2.iloc[0,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[1,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[2,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex, Xa2.iloc[3,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[4,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[5,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[6,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[7,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex, Xa2.iloc[8,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[9,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[10,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[11,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[12,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex, Xa2.iloc[13,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[14,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[15,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[16,ejex], color='blue', lw=5,   label='G2')
ax.plot(ejex, Xa2.iloc[17,ejex], color='blue', lw=5, label='G2')
ax.plot(ejex, Xa2.iloc[18,ejex], color='blue',lw=5, label='G2')
ax.plot(ejex,Xa2.iloc[19,ejex], color='blue', lw=5,   label='G2')
#ax.legend(loc='best', frameon=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(5, 5,figsize=(12,6))
ejex=np.arange(0,62,1)
fig.suptitle("Fig. Plot of mean values of the first 20 channels by each of the  7 groups-DDG training dataset",fontsize=16)
ax[0,0].plot(ejex, Xa1.iloc[0,ejex], color='black',lw=3, label='G1')
ax[0,0].plot(ejex,Xa2.iloc[0,ejex], color='blue', lw=3,  label='G1')
ax[0,1].plot(ejex, Xa1.iloc[1,ejex], color='black',lw=3, label='G1')
ax[0,1].plot(ejex,Xa2.iloc[1,ejex], color='blue', lw=3,  label='G1')
ax[0,2].plot(ejex,Xa1.iloc[2,ejex], color='black', lw=3,  label='G1')
ax[0,2].plot(ejex, Xa2.iloc[2,ejex], color='blue', lw=3, label='G1')
ax[0,3].plot(ejex,Xa1.iloc[3,ejex], color='black', lw=3,   label='G2')
ax[0,3].plot(ejex,Xa2.iloc[3,ejex], color='blue', lw=3,   label='G2')
ax[0,4].plot(ejex,Xa1.iloc[4,ejex], color='black', lw=3,   label='G2')
ax[0,4].plot(ejex, Xa2.iloc[4,ejex], color='blue', lw=3, label='G2')
ax[1,0].plot(ejex, Xa1.iloc[5,ejex], color='black',lw=3, label='G1')
ax[1,0].plot(ejex,Xa2.iloc[5,ejex], color='blue', lw=3,  label='G1')
ax[1,1].plot(ejex, Xa1.iloc[6,ejex], color='black',lw=3, label='G1')
ax[1,1].plot(ejex,Xa2.iloc[6,ejex], color='blue', lw=3,  label='G1')
ax[1,2].plot(ejex, Xa1.iloc[7,ejex], color='black', lw=3, label='G1')
ax[1,2].plot(ejex, Xa2.iloc[7,ejex], color='blue',lw=3, label='G2')
ax[1,3].plot(ejex,Xa1.iloc[8,ejex], color='black', lw=3,   label='G2')
ax[1,3].plot(ejex,Xa2.iloc[8,ejex], color='blue', lw=3,   label='G2')
ax[1,4].plot(ejex,Xa1.iloc[9,ejex], color='black', lw=3,   label='G2')
ax[1,4].plot(ejex, Xa2.iloc[9,ejex], color='blue', lw=3, label='G2')
ax[2,0].plot(ejex,Xa1.iloc[10,ejex], color='black', lw=3,  label='G1')
ax[2,0].plot(ejex, Xa2.iloc[10,ejex], color='blue', lw=3, label='G1')
ax[2,1].plot(ejex, Xa1.iloc[11,ejex], color='black',lw=3, label='G1')
ax[2,1].plot(ejex,Xa2.iloc[11,ejex], color='blue', lw=3,  label='G1')
ax[2,2].plot(ejex,Xa1.iloc[12,ejex], color='black', lw=3,  label='G1')
ax[2,2].plot(ejex, Xa2.iloc[12,ejex], color='blue', lw=3, label='G1')
ax[2,3].plot(ejex,Xa1.iloc[13,ejex], color='black', lw=3,   label='G2')
ax[2,3].plot(ejex,Xa2.iloc[13,ejex], color='blue', lw=3,   label='G2')
ax[2,4].plot(ejex,Xa1.iloc[14,ejex], color='black', lw=3,   label='G2')
ax[2,4].plot(ejex, Xa2.iloc[14,ejex], color='blue', lw=3, label='G2')
ax[3,0].plot(ejex, Xa1.iloc[15,ejex], color='black',lw=3, label='G1')
ax[3,0].plot(ejex,Xa2.iloc[15,ejex], color='blue', lw=3,  label='G1')
ax[3,1].plot(ejex, Xa1.iloc[16,ejex], color='black',lw=3, label='G1')
ax[3,1].plot(ejex,Xa2.iloc[16,ejex], color='blue', lw=3,  label='G1')
ax[3,2].plot(ejex,Xa1.iloc[17,ejex], color='black', lw=3,  label='G1')
ax[3,2].plot(ejex, Xa2.iloc[17,ejex], color='blue', lw=3, label='G1')
ax[3,3].plot(ejex,Xa1.iloc[18,ejex], color='black', lw=3,   label='G2')
ax[3,3].plot(ejex,Xa2.iloc[18,ejex], color='blue', lw=3,   label='G2')
ax[3,4].plot(ejex,Xa1.iloc[19,ejex], color='black', lw=3,   label='G2')
ax[3,4].plot(ejex, Xa2.iloc[19,ejex], color='blue', lw=3, label='G2')
ax[4,0].plot(ejex, Xa1.iloc[20,ejex], color='black',lw=3, label='G1')
ax[4,0].plot(ejex,Xa2.iloc[20,ejex], color='blue', lw=3,  label='G1')
ax[4,1].plot(ejex, Xa1.iloc[21,ejex], color='black',lw=3, label='G1')
ax[4,1].plot(ejex,Xa2.iloc[21,ejex], color='blue', lw=3,  label='G1')
ax[4,2].plot(ejex,Xa1.iloc[22,ejex], color='black', lw=3,  label='G1')
ax[4,2].plot(ejex, Xa2.iloc[22,ejex], color='blue', lw=3, label='G1')
ax[4,3].plot(ejex,Xa1.iloc[23,ejex], color='black', lw=3,   label='G2')
ax[4,3].plot(ejex,Xa2.iloc[23,ejex], color='blue', lw=3,   label='G2')
ax[4,4].plot(ejex,Xa1.iloc[24,ejex], color='black', lw=3,   label='G2')
ax[4,4].plot(ejex, Xa2.iloc[24,ejex], color='blue', lw=3, label='G2')
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,62,4)
fig.suptitle("Fig. Plot of mean values for the first 50 channels-FD training dataset",fontsize=16)
ax.plot(ejex, Xa.iloc[0,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[1,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[2,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[3,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[4,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[5,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[6,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[7,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[8,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa.iloc[9,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[10,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[11,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[12,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[13,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[14,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[15,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[16,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[17,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[18,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[19,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[20,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[21,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[22,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[23,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[24,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[25,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa.iloc[26,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[27,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[28,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[29,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[30,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[31,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[32,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[33,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[34,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[35,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[36,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[37,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[38,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[39,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[40,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[41,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[42,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa.iloc[43,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[44,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[45,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[46,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[47,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[48,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[49,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[50,ejex], color='black', lw=3, label='G2')
#ax.legend(loc='best', frameon=False)

# %%
#mean of the features in the training set
tempotr=X.reshape(X.shape[2],-1).T
tempodftr=pd.DataFrame(tempotr)
print(tempodftr.shape)
#pyplot.boxplot(tempodftr)
#pyplot.show()
# Out:
# (365180, 144)

# %%
tempodftr.mean()
# Out:
# 0      0.001958
# 1     -0.001101
# 2      0.004495
# 3     -0.015457
# 4      0.002219
#          ...
# 139    0.003232
# 140    0.002838
# 141   -0.001181
# 142   -0.004658
# 143    0.007716
# Length: 144, dtype: float64

# %%
#mean of the features in each group of the training dataset 
temptr=pd.DataFrame(tempotr)
from itertools import cycle
variables= cycle(yo)
print(variables)
temptr['group'] = [next(variables) for variable in range(len(temptr))]

# %%
temptr.groupby('group').mean()
# Out:
#             0         1        2         3         4         5         6    \
# group
# 0      0.002581  0.000595  0.00565 -0.013757  0.001192  0.000204 -0.000541
# 1      0.001335 -0.002797  0.00334 -0.017156  0.003245  0.001542  0.004358
#
#             7         8         9    ...       134       135       136  \
# group                                ...
# 0     -0.005767 -0.002384 -0.003107  ...  0.003164  0.008313 -0.006585
# 1     -0.003776  0.000903  0.000528  ...  0.001964  0.004678 -0.009309
#
#             137       138       139       140       141       142       143
# group
# 0      0.004458 -0.007886  0.006484  0.004493 -0.000461 -0.006541  0.007822
# 1      0.003556 -0.005470 -0.000020  0.001184 -0.001902 -0.002774  0.007610
#
# [2 rows x 144 columns]

# %% [markdown]
# ### Distances

# %%
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.03635147])

# %%
tempoA=X.reshape(X.shape[1],-1).T
print(tempoA.shape)
# Out:
# (848160, 62)

# %%
#media total training
meanTr=tempoA.mean(axis=0)
meanTr.shape
# Out:
# (62,)

# %%
# loading Testing data
Xt, yt = load_data("FaceDetection",split="Test")
# Out:
#  Shape of X =  (3524, 144, 62)
#  Shape of y =  (3524,)
#  New shape of X =  (3524, 62, 144)
#  New shape of y =  (3524, 2)

# %%
yto=np.argmax(yt,axis=1)
yto=np.array(yto,dtype=int)
#print(yto)

# %%
Xta=Xt.mean(axis=0).T
Xta=pd.DataFrame(Xta)

# %%
Xta.shape
# Out:
# (144, 62)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=range(0,62,4)
fig.suptitle("Fig. Plot of mean values for the first 50 channels by group-FD training dataset(red) testing dataset(black)",fontsize=16)
ax.plot(ejex,Xa.iloc[1,ejex], color='red', lw=5, label='G1')
ax.plot(ejex, Xa.iloc[2,ejex], color='red', lw=5, label='G1')
ax.plot(ejex,Xa.iloc[3,ejex], color='red', lw=5, label='G2')
ax.plot(ejex, Xa.iloc[4,ejex], color='red', lw=5,  label='G1')
ax.plot(ejex,Xa.iloc[5,ejex], color='red', lw=5, label='G2')
ax.plot(ejex, Xa.iloc[6,ejex], color='red',lw=5, label='G1')
ax.plot(ejex,Xa.iloc[7,ejex], color='red', lw=5, label='G2')
ax.plot(ejex, Xa.iloc[8,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa.iloc[9,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[10,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[11,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[12,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[13,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[14,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[15,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[16,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[17,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[18,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[19,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[20,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[21,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[22,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[23,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[24,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[25,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa.iloc[26,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[27,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[28,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[29,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[30,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[31,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[32,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[33,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[34,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa.iloc[35,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[36,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa.iloc[37,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[38,ejex], color='red', lw=3, label='G1')
ax.plot(ejex,Xa.iloc[39,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[40,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[41,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[42,ejex], color='red',lw=3, label='G1')
ax.plot(ejex, Xa.iloc[43,ejex], color='red',lw=3,  label='d1')
ax.plot(ejex,Xa.iloc[44,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa.iloc[45,ejex], color='red', lw=3, label='d3')
ax.plot(ejex,Xa.iloc[46,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[47,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa.iloc[48,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa.iloc[49,ejex], color='red',lw=3,  label='G1')
ax.plot(ejex,Xa.iloc[50,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[0,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xta.iloc[1,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xta.iloc[2,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xta.iloc[3,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[4,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[5,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[6,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[7,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[8,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta.iloc[9,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xta.iloc[10,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xta.iloc[11,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xta.iloc[12,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[13,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[14,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[15,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[16,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[17,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xta.iloc[18,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xta.iloc[19,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xta.iloc[20,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[21,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[22,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[23,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[24,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[25,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xta.iloc[26,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xta.iloc[27,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xta.iloc[28,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xta.iloc[29,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[30,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[31,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[32,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[33,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[34,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xta.iloc[35,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xta.iloc[36,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xta.iloc[37,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[38,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[39,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xta.iloc[40,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xta.iloc[41,ejex], color='black', lw=5, label='G2')
ax.plot(ejex, Xta.iloc[42,ejex], color='black',lw=5,  label='G1')
ax.plot(ejex, Xta.iloc[43,ejex], color='black',lw=5, label='d1')
ax.plot(ejex,Xta.iloc[44,ejex], color='black', lw=5, label='d2')
ax.plot(ejex, Xta.iloc[45,ejex], color='black', lw=5, label='d3')
ax.plot(ejex,Xta.iloc[46,ejex], color='black', lw=5, label='G2')
ax.plot(ejex, Xta.iloc[47,ejex], color='black', lw=5,label='G1')
ax.plot(ejex,Xta.iloc[48,ejex], color='black', lw=5, label='G2')
ax.plot(ejex, Xta.iloc[49,ejex], color='black',lw=5, label='G2')
ax.plot(ejex,Xta.iloc[50,ejex], color='black', lw=5, label='G2')
#ax.legend(loc='best', frameon=False)

# %%
#class size in testing
import numpy as np
np.sum(yt,axis=0)
# Out:
# array([1762, 1762])

# %%
#Boxplots of features in the testing dataset
tempote=Xt.reshape(Xt.shape[2],-1).T
tempodfte=pd.DataFrame(tempote)
print(tempodfte.shape)
#pyplot.boxplot(tempodfte)
#pyplot.show()
# Out:
# (218488, 144)

# %%
ar=np.sum(yt,axis=0)
np.max(ar/Xt.shape[0])
# Out:
# 0.5

# %%
#mean of the features in each group of the training dataset 
tempte=pd.DataFrame(tempote)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempte['group'] = [next(variables) for variable in range(len(tempte))]

# %%
tempte.groupby('group').mean()
# Out:
#             0         1         2         3         4         5         6    \
# group
# 0     -0.007845 -0.003624 -0.000272 -0.001297 -0.015800  0.009841  0.006383
# 1     -0.008528 -0.006563 -0.003127 -0.006420 -0.013416  0.009750  0.004035
#
#             7         8         9    ...       134       135       136  \
# group                                ...
# 0     -0.007336  0.011511 -0.004950  ... -0.020918 -0.025735 -0.010292
# 1     -0.006398  0.011632 -0.005993  ... -0.032219 -0.015570 -0.006611
#
#             137       138       139       140       141       142       143
# group
# 0     -0.002852  0.002248  0.006081  0.008045  0.003063 -0.011197  0.000665
# 1      0.000942 -0.001556  0.000457  0.009452  0.006471 -0.006413  0.000180
#
# [2 rows x 144 columns]

# %%
tempoA=X.reshape(X.shape[1],-1).T
print(tempoA.shape)
# Out:
# (848160, 62)

# %%
tempoA1=Xt.reshape(Xt.shape[1],-1).T
print(tempoA1.shape)
# Out:
# (507456, 62)

# %%
tempoB=pd.DataFrame(tempoA)
from itertools import cycle
variables= cycle(yo)
print(variables)
tempoB['group'] = [next(variables) for variable in range(len(tempoB))]
#Bboxplot  of features by class
a=tempoB.groupby('group').mean()

# %%
tempoB1=pd.DataFrame(tempoA1)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempoB1['group'] = [next(variables) for variable in range(len(tempoB1))]
#Bboxplot  of features by class
a1=tempoB1.groupby('group').mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=range(0,62,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-FD training dataset",fontsize=16)
ax.plot(ejex, a.iloc[0,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,a.iloc[1,ejex], color='blue', lw=3, label='G2')
ax.legend(loc='best', frameon=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=range(0,62,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-FD testing dataset",fontsize=16)
ax.plot(ejex, a1.iloc[0,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,a1.iloc[1,ejex], color='blue', lw=3, label='G2')
ax.legend(loc='best', frameon=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#f = plt.figure(figsize=(10,3))
fig, (ax1, ax2) = plt.subplots(2,figsize=(20,10))
fig.suptitle('Horizontally stacked subplots')
#fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,62,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-FD trainng (above) and testing(below) dataset",fontsize=16)
ax1.plot(ejex, a.iloc[0,ejex], color='black',lw=3, label='G1')
ax1.plot(ejex,a.iloc[1,ejex], color='red', lw=3, label='G2')
ax1.legend(loc='best', frameon=False)
ax2.plot(ejex, a1.iloc[0,ejex], color='black',lw=3, label='G1')
ax2.plot(ejex,a1.iloc[1,ejex], color='red', lw=3, label='G2')
ax2.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# ### Feature Selection

# %%
#Feature selection
from sklearn.feature_selection import  mutual_info_classif, SelectPercentile, f_classif
ym=tempoB['group']
Xm=tempoB.iloc[:,0:62]
scores = mutual_info_classif(Xm,ym)
scores /= scores.max()
importance=[i for i,v in enumerate(scores) if v > .5]
len(importance)*100/62
# Out:
# 17.741935483870968

# %%
selector = SelectPercentile(f_classif, percentile=30)
Xm_new=selector.fit_transform(Xm, ym)
scores = -np.log10(selector.pvalues_)
#scores /= scores.max()
#print(scores)
#critical p-value=.15
importance=[i for i,v in enumerate(scores) if v > .8239]
len(importance)*100/62
# Out:
# 11.290322580645162

# %%
means=tempte.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.04506694])

# %%
import numpy as np
Xb= np.concatenate((X, Xt),axis=0)
print(Xb.shape)
# Out:
# (9414, 62, 144)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
tempo=X.reshape(X.shape[2],-1).T
#print(tempo.shape)
X = scaler.fit_transform(X.reshape(X.shape[2], -1)).reshape(X.shape)
Xt = scaler.fit_transform(Xt.reshape(Xt.shape[2], -1)).reshape(Xt.shape)
Xb = scaler.fit_transform(Xb.reshape(Xb.shape[2], -1)).reshape(Xb.shape)
X1 = scaler.fit_transform(tempo)
#print(X)
tempodf=pd.DataFrame(X1)
print(tempodf.shape)
pyplot.boxplot(tempodf)
#pyplot.show()
# Out:
# (365180, 144)
# {'whiskers': [<matplotlib.lines.Line2D at 0x1890610d940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1890606c710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1890610f6e0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1890606f470>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1891625e960>,
# ...
#  'means': []}

# %%
tempoA1=Xt.reshape(Xt.shape[1],-1).T
print(tempoA1.shape)
# Out:
# (507456, 62)

# %%
#media total testung
meanTe=tempoA1.mean(axis=0)
meanTe.shape
# Out:
# (62,)

# %%
#Distance Training and Testsing
from scipy.spatial import distance
dst = distance.euclidean(meanTr, meanTe)
dst
# Out:
# 0.07911671507448872

# %% [markdown]
# ### Stationarity

# %%
#Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
Xest = tempoB.iloc[20,0:62]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.559192
# p-value: 0.000153
# Critical Values:
# 	1%: -3.544
# 	5%: -2.911
# 	10%: -2.593

# %%
sm.graphics.tsa.plot_acf(Xest, alpha=.05)
