# %% [markdown]
# ### Data engineering
# ### Dataset:NATOPS
# ### Author: Edgar Acuna
# ### Created: March 16, 2025

# %%
# imports
import numpy as np
from numpy import mean
from numpy import std, unique
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

# %%
import pandas as pd
from aeon.datasets import load_classification
from sklearn import preprocessing

def load_data(dataset, split="Train"):
    if split=="Train":
        X, y = load_classification(dataset, split="Train")
    else:
        X, y = load_classification(dataset, split="Test")
    print(" Shape of X = ", X.shape)
    print(" Shape of y = ", y.shape)
    #Swap dimensions so features are the third dimension
    X = X.swapaxes(1, 2)
    print(" New shape of X = ", X.shape)
    #prepare y
    y = pd.DataFrame(y)
    enc = preprocessing.OneHotEncoder(dtype=int)
    enc.fit(y)
    y = enc.transform(y).toarray()
    print(" New shape of y = ", y.shape)
    return X, y

# %% [markdown]
# ### Training Data

# %%
# loading Training data
X, y = load_data("NATOPS",split="Train")
# Out:
#  Shape of X =  (180, 24, 51)
#  Shape of y =  (180,)
#  New shape of X =  (180, 51, 24)
#  New shape of y =  (180, 6)

# %%
#class size in training 
import numpy as np
np.sum(y,axis=0)
# Out:
# array([30, 30, 30, 30, 30, 30])

# %%
X.shape
# Out:
# (180, 51, 24)

# %%
import numpy as np
yo=np.argmax(y,axis=1)
yo=np.array(yo,dtype=int)
#print(yo)

# %%
X1=X[yo==0]
X2=X[yo==1]
X3=X[yo==2]
X4=X[yo==3]
X5=X[yo==4]
X6=X[yo==5]
print(X3.shape)
# Out:
# (30, 51, 24)

# %%
Xa1=X1.mean(axis=0).T
Xa1=pd.DataFrame(Xa1)
Xa2=X2.mean(axis=0).T
Xa2=pd.DataFrame(Xa2)
Xa3=X3.mean(axis=0).T
Xa3=pd.DataFrame(Xa3)
Xa4=X4.mean(axis=0).T
Xa4=pd.DataFrame(Xa4)
Xa5=X5.mean(axis=0).T
Xa5=pd.DataFrame(Xa5)
Xa6=X6.mean(axis=0).T
Xa6=pd.DataFrame(Xa6)
print(Xa2.shape)
# Out:
# (24, 51)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,51,1)
fig.suptitle("Fig. Plot of mean values by channel in each group-NATOPS training dataset",fontsize=16)
ax.plot(ejex, Xa1.iloc[0,ejex], color='red',lw=3,  label='d1')
ax.plot(ejex,Xa1.iloc[1,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa1.iloc[2,ejex], color='red', lw=3, label='d3')
ax.plot(ejex,Xa1.iloc[3,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[4,ejex], color='red', lw=3, label='G1')
ax.plot(ejex,Xa1.iloc[5,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[6,ejex], color='red',lw=3, label='G1')
ax.plot(ejex,Xa1.iloc[7,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[8,ejex], color='red',lw=3, label='G1')
ax.plot(ejex, Xa1.iloc[9,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa1.iloc[10,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa1.iloc[11,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa1.iloc[12,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[13,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa1.iloc[14,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[15,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa1.iloc[16,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[17,ejex], color='red',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa1.iloc[18,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa1.iloc[19,ejex], color='red', lw=3, label='d2')
ax.plot(ejex, Xa1.iloc[20,ejex], color='red', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa1.iloc[21,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa1.iloc[22,ejex], color='red', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa1.iloc[23,ejex], color='red', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[0,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa2.iloc[1,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa2.iloc[2,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa2.iloc[3,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[4,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[5,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[6,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[7,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[8,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa2.iloc[9,ejex], color='black',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa2.iloc[10,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa2.iloc[11,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa2.iloc[12,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[13,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[14,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[15,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[16,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[17,ejex], color='black',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa2.iloc[18,ejex], color='red',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa2.iloc[19,ejex], color='black', lw=3, label='d2')
ax.plot(ejex, Xa2.iloc[20,ejex], color='black', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa2.iloc[21,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa2.iloc[22,ejex], color='black', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa2.iloc[23,ejex], color='black', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[0,ejex], color='blue',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa3.iloc[1,ejex], color='blue', lw=3, label='d2')
ax.plot(ejex, Xa3.iloc[2,ejex], color='blue', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa3.iloc[3,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[4,ejex], color='blue', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa3.iloc[5,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[6,ejex], color='blue',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa3.iloc[7,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[8,ejex], color='blue',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa3.iloc[9,ejex], color='blue',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa3.iloc[10,ejex], color='blue', lw=3, label='d2')
ax.plot(ejex, Xa3.iloc[11,ejex], color='blue', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa3.iloc[12,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[13,ejex], color='blue', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa3.iloc[14,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[15,ejex], color='blue',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa3.iloc[16,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[17,ejex], color='blue',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa3.iloc[18,ejex], color='blue',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa3.iloc[19,ejex], color='blue', lw=3, label='d2')
ax.plot(ejex, Xa3.iloc[20,ejex], color='blue', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa3.iloc[21,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa3.iloc[22,ejex], color='blue', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa3.iloc[23,ejex], color='blue', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[0,ejex], color='yellow',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa4.iloc[1,ejex], color='yellow', lw=3, label='d2')
ax.plot(ejex, Xa4.iloc[2,ejex], color='yellow', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa4.iloc[3,ejex], color='yellow', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[4,ejex], color='yellow', alpha=0.5, label='G1')
ax.plot(ejex,Xa4.iloc[5,ejex], color='yellow', label='G2')
ax.plot(ejex, Xa4.iloc[6,ejex], color='yellow',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa4.iloc[7,ejex], color='yellow', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[8,ejex], color='yellow',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa4.iloc[9,ejex], color='yellow',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa4.iloc[10,ejex], color='yellow', lw=3, label='d2')
ax.plot(ejex, Xa4.iloc[11,ejex], color='yellow', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa4.iloc[12,ejex], color='yellow', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[13,ejex], color='yellow', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa4.iloc[14,ejex], color='yellow', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[15,ejex], color='yellow',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa4.iloc[16,ejex], color='yellow', lw=3, label='G2')
ax.plot(ejex, Xa4.iloc[17,ejex], color='yellow',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa4.iloc[18,ejex], color='yellow',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa4.iloc[19,ejex], color='yellow', lw=3, label='d2')
ax.plot(ejex, Xa4.iloc[20,ejex], color='yellow',alpha=0.5, label='d3')
ax.plot(ejex,Xa4.iloc[21,ejex], color='yellow',label='G2')
ax.plot(ejex, Xa4.iloc[22,ejex], color='yellow', label='G1')
ax.plot(ejex,Xa4.iloc[23,ejex], color='yellow',label='G2')
ax.plot(ejex, Xa5.iloc[0,ejex], color='green',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa5.iloc[1,ejex], color='green', lw=3, label='d2')
ax.plot(ejex, Xa5.iloc[2,ejex], color='green', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa5.iloc[3,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[4,ejex], color='green', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa5.iloc[5,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[6,ejex], color='green',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa5.iloc[7,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[8,ejex], color='green',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa5.iloc[9,ejex], color='green',lw=3, alpha=0.5, label='d1')
ax.plot(ejex,Xa5.iloc[10,ejex], color='green', lw=3, label='d2')
ax.plot(ejex, Xa5.iloc[11,ejex], color='green', lw=3, alpha=0.5, label='d3')
ax.plot(ejex,Xa5.iloc[12,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[13,ejex], color='green', lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa5.iloc[14,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[15,ejex], color='green',lw=3, alpha=0.5, label='G1')
ax.plot(ejex,Xa5.iloc[16,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[17,ejex], color='green',lw=3, alpha=0.5, label='G1')
ax.plot(ejex, Xa5.iloc[18,ejex], color='green',lw=3,  label='d1')
ax.plot(ejex,Xa5.iloc[19,ejex], color='green', lw=3, label='d2')
ax.plot(ejex, Xa5.iloc[20,ejex], color='green', lw=3,  label='d3')
ax.plot(ejex,Xa5.iloc[21,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa5.iloc[22,ejex], color='green', lw=3,  label='G1')
ax.plot(ejex,Xa5.iloc[23,ejex], color='green', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[0,ejex], color='magenta',lw=3,  label='d1')
ax.plot(ejex,Xa6.iloc[1,ejex], color='magenta', lw=3, label='d2')
ax.plot(ejex, Xa6.iloc[2,ejex], color='magenta', lw=3,  label='d3')
ax.plot(ejex,Xa6.iloc[3,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[4,ejex], color='magenta', lw=3, label='G1')
ax.plot(ejex,Xa6.iloc[5,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[6,ejex], color='magenta',lw=3, label='G1')
ax.plot(ejex,Xa6.iloc[7,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[8,ejex], color='magenta',lw=3, label='G1')
ax.plot(ejex, Xa6.iloc[9,ejex], color='magenta',lw=3,  label='d1')
ax.plot(ejex,Xa6.iloc[10,ejex], color='magenta', lw=3, label='d2')
ax.plot(ejex, Xa6.iloc[11,ejex], color='magenta', lw=3,  label='d3')
ax.plot(ejex,Xa6.iloc[12,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[13,ejex], color='magenta', lw=3, label='G1')
ax.plot(ejex,Xa6.iloc[14,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[15,ejex], color='magenta',lw=3, label='G1')
ax.plot(ejex,Xa6.iloc[16,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[17,ejex], color='magenta',lw=3,  label='G1')
ax.plot(ejex, Xa6.iloc[18,ejex], color='magenta',lw=3,  label='d1')
ax.plot(ejex,Xa6.iloc[19,ejex], color='magenta', lw=3, label='d2')
ax.plot(ejex, Xa6.iloc[20,ejex], color='magenta', lw=3, label='d3')
ax.plot(ejex,Xa6.iloc[21,ejex], color='magenta', lw=3, label='G2')
ax.plot(ejex, Xa6.iloc[22,ejex], color='magenta', lw=3,  label='G1')
ax.plot(ejex,Xa6.iloc[23,ejex], color='magenta', lw=3, label='G2')
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
Xa=X.mean(axis=0).T
Xa=pd.DataFrame(Xa)

# %%
fig, axs = plt.subplots(4, 6,figsize=(12,6))
ejex=np.arange(0,51,1)
fig.suptitle("Fig. Plot of mean values by channel in each group-NATOPS training dataset",fontsize=16)
axs[0,0].plot(ejex, Xa1.iloc[0,ejex], color='black',lw=3,  label='d1')
axs[0,0].plot(ejex,Xa2.iloc[0,ejex], color='red', lw=3, label='d2')
axs[0,0].plot(ejex, Xa3.iloc[0,ejex], color='blue', lw=3, label='d3')
axs[0,0].plot(ejex,Xa4.iloc[0,ejex], color='cyan', lw=3, label='G2')
axs[0,0].plot(ejex, Xa5.iloc[0,ejex], color='magenta', lw=3, label='G1')
axs[0,0].plot(ejex,Xa6.iloc[0,ejex], color='orange', lw=3, label='G2')
axs[0,0].set_title("Channel 1")
axs[0,1].plot(ejex, Xa1.iloc[1,ejex], color='black',lw=3, label='G1')
axs[0,1].plot(ejex,Xa2.iloc[1,ejex], color='red', lw=3, label='G2')
axs[0,1].plot(ejex, Xa3.iloc[1,ejex], color='blue',lw=3, label='G1')
axs[0,1].plot(ejex, Xa4.iloc[1,ejex], color='cyan',lw=3,  label='d1')
axs[0,1].plot(ejex,Xa5.iloc[1,ejex], color='magenta', lw=3, label='d2')
axs[0,1].plot(ejex, Xa6.iloc[1,ejex], color='orange', lw=3, label='d3')
axs[0,1].set_title("Channel 2")
axs[0,2].plot(ejex,Xa1.iloc[2,ejex], color='black', lw=3, label='G2')
axs[0,2].plot(ejex, Xa2.iloc[2,ejex], color='red', lw=3,  label='G1')
axs[0,2].plot(ejex,Xa3.iloc[2,ejex], color='blue', lw=3, label='G2')
axs[0,2].plot(ejex, Xa4.iloc[2,ejex], color='cyan',lw=3, label='G1')
axs[0,2].plot(ejex,Xa5.iloc[2,ejex], color='magenta', lw=3, label='G2')
axs[0,2].plot(ejex, Xa6.iloc[2,ejex], color='orange',lw=3, label='G1')
axs[0,2].set_title("Channel 3")
axs[0,3].plot(ejex, Xa1.iloc[3,ejex], color='black',lw=3, label='d1')
axs[0,3].plot(ejex,Xa2.iloc[3,ejex], color='red', lw=3, label='d2')
axs[0,3].plot(ejex, Xa3.iloc[3,ejex], color='blue', lw=3, label='d3')
axs[0,3].plot(ejex,Xa4.iloc[3,ejex], color='cyan', lw=3, label='G2')
axs[0,3].plot(ejex, Xa5.iloc[3,ejex], color='magenta', lw=3, label='G1')
axs[0,3].plot(ejex,Xa6.iloc[3,ejex], color='orange', lw=3, label='G2')
axs[0,3].set_title("Channel 4")
axs[0,4].plot(ejex, Xa1.iloc[4,ejex], color='black',lw=3, label='d1')
axs[0,4].plot(ejex,Xa2.iloc[4,ejex], color='red', lw=3, label='d2')
axs[0,4].plot(ejex, Xa3.iloc[4,ejex], color='blue', lw=3, label='d3')
axs[0,4].plot(ejex,Xa4.iloc[4,ejex], color='cyan', lw=3, label='G2')
axs[0,4].plot(ejex, Xa5.iloc[4,ejex], color='magenta', lw=3,label='G1')
axs[0,4].plot(ejex,Xa6.iloc[4,ejex], color='orange', lw=3, label='G2')
axs[0,4].set_title("Channel 5")
axs[0,5].plot(ejex, Xa1.iloc[5,ejex], color='black',lw=3,label='d1')
axs[0,5].plot(ejex,Xa2.iloc[5,ejex], color='red', lw=3, label='d2')
axs[0,5].plot(ejex, Xa3.iloc[5,ejex], color='blue', lw=3,  label='d3')
axs[0,5].plot(ejex,Xa4.iloc[5,ejex], color='cyan', lw=3, label='G2')
axs[0,5].plot(ejex, Xa5.iloc[5,ejex], color='magenta', lw=3, label='G1')
axs[0,5].plot(ejex,Xa6.iloc[5,ejex], color='orange', lw=3, label='G2')
axs[0,5].set_title("Channel 6")
axs[1,0].plot(ejex,Xa1.iloc[6,ejex], color='black', lw=3, label='d2')
axs[1,0].plot(ejex, Xa2.iloc[6,ejex], color='red', lw=3, label='d3')
axs[1,0].plot(ejex,Xa3.iloc[6,ejex], color='blue', lw=3, label='G2')
axs[1,0].plot(ejex, Xa4.iloc[6,ejex], color='cyan', lw=3, label='G1')
axs[1,0].plot(ejex,Xa5.iloc[6,ejex], color='magenta', lw=3, label='G2')
axs[1,0].plot(ejex, Xa6.iloc[6,ejex], color='orange',lw=3, label='G1')
axs[1,0].set_title("Channel 7")
axs[1,1].plot(ejex,Xa1.iloc[7,ejex], color='black', lw=3, label='G2')
axs[1,1].plot(ejex, Xa2.iloc[7,ejex], color='red',lw=3, label='G1')
axs[1,1].plot(ejex, Xa3.iloc[7,ejex], color='blue',lw=3,  label='d1')
axs[1,1].plot(ejex,Xa4.iloc[7,ejex], color='cyan', lw=3, label='d2')
axs[1,1].plot(ejex, Xa5.iloc[7,ejex], color='magenta', lw=3,  label='d3')
axs[1,1].plot(ejex,Xa6.iloc[7,ejex], color='orange', lw=3, label='G2')
axs[1,1].set_title("Channel 8")
axs[1,2].plot(ejex,Xa1.iloc[8,ejex], color='black', lw=3, label='G2')
axs[1,2].plot(ejex, Xa2.iloc[8,ejex], color='red',lw=3, label='G1')
axs[1,2].plot(ejex, Xa3.iloc[8,ejex], color='blue',lw=3, label='d1')
axs[1,2].plot(ejex,Xa4.iloc[8,ejex], color='cyan', lw=3, label='d2')
axs[1,2].plot(ejex, Xa5.iloc[8,ejex], color='magenta', lw=3, label='d3')
axs[1,2].plot(ejex,Xa6.iloc[8,ejex], color='orange', lw=3, label='G2')
axs[1,2].set_title("Channel 9")
axs[1,3].plot(ejex,Xa1.iloc[9,ejex], color='black', lw=3, label='G2')
axs[1,3].plot(ejex, Xa2.iloc[9,ejex], color='red',lw=3,  label='G1')
axs[1,3].plot(ejex, Xa3.iloc[9,ejex], color='blue',lw=3, label='d1')
axs[1,3].plot(ejex,Xa4.iloc[9,ejex], color='cyan', lw=3, label='d2')
axs[1,3].plot(ejex, Xa5.iloc[9,ejex], color='magenta', lw=3, label='d3')
axs[1,3].plot(ejex,Xa6.iloc[9,ejex], color='orange', lw=3, label='G2')
axs[1,3].set_title("Channel 10")
axs[1,4].plot(ejex,Xa1.iloc[10,ejex], color='black', lw=3, label='G2')
axs[1,4].plot(ejex, Xa2.iloc[10,ejex], color='red',lw=3, label='G1')
axs[1,4].plot(ejex, Xa3.iloc[10,ejex], color='blue',lw=3,  label='d1')
axs[1,4].plot(ejex,Xa4.iloc[10,ejex], color='cyan', lw=3, label='d2')
axs[1,4].plot(ejex, Xa5.iloc[10,ejex], color='magenta', lw=3, label='d3')
axs[1,4].plot(ejex,Xa6.iloc[10,ejex], color='orange', lw=3, label='G2')
axs[1,4].set_title("Channel 11")
axs[1,5].plot(ejex,Xa1.iloc[11,ejex], color='black', lw=3, label='G2')
axs[1,5].plot(ejex, Xa2.iloc[11,ejex], color='red',lw=3, label='G1')
axs[1,5].plot(ejex, Xa3.iloc[11,ejex], color='blue',lw=3, label='d1')
axs[1,5].plot(ejex,Xa4.iloc[11,ejex], color='cyan', lw=3, label='d2')
axs[1,5].plot(ejex, Xa5.iloc[11,ejex], color='magenta', lw=3,label='d3')
axs[1,5].plot(ejex,Xa6.iloc[11,ejex], color='orange', lw=3, label='G2')
axs[1,5].set_title("Channel 12")
axs[2,0].plot(ejex, Xa1.iloc[12,ejex], color='black',lw=3,  label='d1')
axs[2,0].plot(ejex,Xa2.iloc[12,ejex], color='red', lw=3, label='d2')
axs[2,0].plot(ejex, Xa3.iloc[12,ejex], color='blue', lw=3, label='d3')
axs[2,0].plot(ejex,Xa4.iloc[12,ejex], color='cyan', lw=3, label='G2')
axs[2,0].plot(ejex, Xa5.iloc[12,ejex], color='magenta', lw=3, label='G1')
axs[2,0].plot(ejex,Xa6.iloc[12,ejex], color='orange', lw=3, label='G2')
axs[2,1].plot(ejex, Xa1.iloc[13,ejex], color='black',lw=3, label='G1')
axs[2,1].plot(ejex,Xa2.iloc[13,ejex], color='red', lw=3, label='G2')
axs[2,1].plot(ejex, Xa3.iloc[13,ejex], color='blue',lw=3, label='G1')
axs[2,1].plot(ejex, Xa4.iloc[13,ejex], color='cyan',lw=3,  label='d1')
axs[2,1].plot(ejex,Xa5.iloc[13,ejex], color='magenta', lw=3, label='d2')
axs[2,1].plot(ejex, Xa6.iloc[13,ejex], color='orange', lw=3, label='d3')
axs[2,2].plot(ejex,Xa1.iloc[14,ejex], color='black', lw=3, label='G2')
axs[2,2].plot(ejex, Xa2.iloc[14,ejex], color='red', lw=3,label='G1')
axs[2,2].plot(ejex,Xa3.iloc[14,ejex], color='blue', lw=3, label='G2')
axs[2,2].plot(ejex, Xa4.iloc[14,ejex], color='cyan',lw=3, label='G1')
axs[2,2].plot(ejex,Xa5.iloc[14,ejex], color='magenta', lw=3, label='G2')
axs[2,2].plot(ejex, Xa6.iloc[14,ejex], color='orange',lw=3, label='G1')
axs[2,3].plot(ejex, Xa1.iloc[15,ejex], color='black',lw=3, label='d1')
axs[2,3].plot(ejex,Xa2.iloc[15,ejex], color='red', lw=3, label='d2')
axs[2,3].plot(ejex, Xa3.iloc[15,ejex], color='blue', lw=3, label='d3')
axs[2,3].plot(ejex,Xa4.iloc[15,ejex], color='cyan', lw=3, label='G2')
axs[2,3].plot(ejex, Xa5.iloc[15,ejex], color='magenta', lw=3, label='G1')
axs[2,3].plot(ejex,Xa6.iloc[15,ejex], color='orange', lw=3, label='G2')
axs[2,4].plot(ejex, Xa1.iloc[16,ejex], color='black',lw=3, label='d1')
axs[2,4].plot(ejex,Xa2.iloc[16,ejex], color='red', lw=3, label='d2')
axs[2,4].plot(ejex, Xa3.iloc[16,ejex], color='blue', lw=3,  label='d3')
axs[2,4].plot(ejex,Xa4.iloc[16,ejex], color='cyan', lw=3, label='G2')
axs[2,4].plot(ejex, Xa5.iloc[16,ejex], color='magenta', lw=3, label='G1')
axs[2,4].plot(ejex,Xa6.iloc[16,ejex], color='orange', lw=3, label='G2')
axs[2,5].plot(ejex, Xa1.iloc[17,ejex], color='black',lw=3, label='d1')
axs[2,5].plot(ejex,Xa2.iloc[17,ejex], color='red', lw=3, label='d2')
axs[2,5].plot(ejex, Xa3.iloc[17,ejex], color='blue', lw=3, label='d3')
axs[2,5].plot(ejex,Xa4.iloc[17,ejex], color='cyan', lw=3, label='G2')
axs[2,5].plot(ejex, Xa5.iloc[17,ejex], color='magenta', lw=3,  label='G1')
axs[2,5].plot(ejex,Xa6.iloc[17,ejex], color='orange', lw=3, label='G2')
axs[3,0].plot(ejex,Xa1.iloc[18,ejex], color='black', lw=3, label='d2')
axs[3,0].plot(ejex, Xa2.iloc[18,ejex], color='red', lw=3, label='d3')
axs[3,0].plot(ejex,Xa3.iloc[18,ejex], color='blue', lw=3, label='G2')
axs[3,0].plot(ejex, Xa4.iloc[18,ejex], color='cyan', lw=3, label='G1')
axs[3,0].plot(ejex,Xa5.iloc[18,ejex], color='magenta', lw=3, label='G2')
axs[3,0].plot(ejex, Xa6.iloc[18,ejex], color='orange',lw=3, label='G1')
axs[3,1].plot(ejex,Xa1.iloc[19,ejex], color='black', lw=3, label='G2')
axs[3,1].plot(ejex, Xa2.iloc[19,ejex], color='red',lw=3,  label='G1')
axs[3,1].plot(ejex, Xa3.iloc[19,ejex], color='blue',lw=3,  label='d1')
axs[3,1].plot(ejex,Xa4.iloc[19,ejex], color='cyan', lw=3, label='d2')
axs[3,1].plot(ejex, Xa5.iloc[19,ejex], color='magenta', lw=3, label='d3')
axs[3,1].plot(ejex,Xa6.iloc[19,ejex], color='orange', lw=3, label='G2')
axs[3,2].plot(ejex,Xa1.iloc[20,ejex], color='black', lw=3, label='G2')
axs[3,2].plot(ejex, Xa2.iloc[20,ejex], color='red',lw=3, label='G1')
axs[3,2].plot(ejex, Xa3.iloc[20,ejex], color='blue',lw=3, label='d1')
axs[3,2].plot(ejex,Xa4.iloc[20,ejex], color='cyan', lw=3, label='d2')
axs[3,2].plot(ejex, Xa5.iloc[20,ejex], color='magenta', lw=3, label='d3')
axs[3,2].plot(ejex,Xa6.iloc[20,ejex], color='orange', lw=3, label='G2')
axs[3,3].plot(ejex,Xa1.iloc[21,ejex], color='black', lw=3, label='G2')
axs[3,3].plot(ejex, Xa2.iloc[21,ejex], color='red',lw=3, label='G1')
axs[3,3].plot(ejex, Xa3.iloc[21,ejex], color='blue',lw=3, label='d1')
axs[3,3].plot(ejex,Xa4.iloc[21,ejex], color='cyan', lw=3, label='d2')
axs[3,3].plot(ejex, Xa5.iloc[21,ejex], color='magenta', lw=3, label='d3')
axs[3,3].plot(ejex,Xa6.iloc[21,ejex], color='orange', lw=3, label='G2')
axs[3,4].plot(ejex,Xa1.iloc[22,ejex], color='black', lw=3, label='G2')
axs[3,4].plot(ejex, Xa2.iloc[22,ejex], color='red',lw=3,  label='G1')
axs[3,4].plot(ejex, Xa3.iloc[22,ejex], color='blue',lw=3, label='d1')
axs[3,4].plot(ejex,Xa4.iloc[22,ejex], color='cyan', lw=3, label='d2')
axs[3,4].plot(ejex, Xa5.iloc[22,ejex], color='magenta', lw=3,  label='d3')
axs[3,4].plot(ejex,Xa6.iloc[22,ejex], color='orange', lw=3, label='G2')
axs[3,5].plot(ejex,Xa1.iloc[23,ejex], color='black', lw=3, label='G2')
axs[3,5].plot(ejex, Xa2.iloc[23,ejex], color='red',lw=3, label='G1')
axs[3,5].plot(ejex, Xa3.iloc[23,ejex], color='blue',lw=3, label='d1')
axs[3,5].plot(ejex,Xa4.iloc[23,ejex], color='cyan', lw=3, label='d2')
axs[3,5].plot(ejex, Xa5.iloc[23,ejex], color='magenta', lw=3,label='d3')
axs[3,5].plot(ejex,Xa6.iloc[23,ejex], color='orange', lw=3, label='G2')
#ax.legend(loc='best', frameon=False)
plt.show()

# %%
#class size in training
import numpy as np
np.sum(y,axis=0)
# Out:
# array([30, 30, 30, 30, 30, 30])

# %%
#Boxplot of features in the traoning dataset
tempotr=X.reshape(X.shape[2],-1).T
tempodftr=pd.DataFrame(tempotr)
print(tempodftr.shape)
pyplot.boxplot(tempodftr)
pyplot.show()
# Out:
# (9180, 24)

# %%
#Boxplots of each feature inthe groups pf the training dataset
temptr=pd.DataFrame(tempotr)
from itertools import cycle
variables= cycle(yo)
print(variables)
temptr['group'] = [next(variables) for variable in range(len(temptr))]
#Bboxplot  of features by class
temptr.boxplot(by='group')
# Out:
# <itertools.cycle object at 0x000002112E572740>
# array([[<Axes: title={'center': '0'}, xlabel='[group]'>,
#         <Axes: title={'center': '1'}, xlabel='[group]'>,
#         <Axes: title={'center': '2'}, xlabel='[group]'>,
#         <Axes: title={'center': '3'}, xlabel='[group]'>,
#         <Axes: title={'center': '4'}, xlabel='[group]'>],
#        [<Axes: title={'center': '5'}, xlabel='[group]'>,
#         <Axes: title={'center': '6'}, xlabel='[group]'>,
#         <Axes: title={'center': '7'}, xlabel='[group]'>,
#         <Axes: title={'center': '8'}, xlabel='[group]'>,
#         <Axes: title={'center': '9'}, xlabel='[group]'>],
#        [<Axes: title={'center': '10'}, xlabel='[group]'>,
#         <Axes: title={'center': '11'}, xlabel='[group]'>,
#         <Axes: title={'center': '12'}, xlabel='[group]'>,
#         <Axes: title={'center': '13'}, xlabel='[group]'>,
#         <Axes: title={'center': '14'}, xlabel='[group]'>],
#        [<Axes: title={'center': '15'}, xlabel='[group]'>,
#         <Axes: title={'center': '16'}, xlabel='[group]'>,
#         <Axes: title={'center': '17'}, xlabel='[group]'>,
#         <Axes: title={'center': '18'}, xlabel='[group]'>,
#         <Axes: title={'center': '19'}, xlabel='[group]'>],
#        [<Axes: title={'center': '20'}, xlabel='[group]'>,
#         <Axes: title={'center': '21'}, xlabel='[group]'>,
#         <Axes: title={'center': '22'}, xlabel='[group]'>,
#         <Axes: title={'center': '23'}, xlabel='[group]'>, <Axes: >]],
#       dtype=object)

# %%
temptr.groupby('group').mean()
# Out:
#              0         1         2         3         4         5         6   \
# group
# 0     -0.307139 -0.262256 -0.300345 -0.234376 -0.290344 -0.274300 -0.274802
# 1     -0.443707 -0.383491 -0.403869 -0.410926 -0.428687 -0.407418 -0.360711
# 2     -0.519359 -0.467242 -0.508294 -0.435548 -0.507923 -0.467496 -0.471168
# 3     -0.302513 -0.295406 -0.258949 -0.338549 -0.271237 -0.294650 -0.231829
# 4     -0.332056 -0.330086 -0.314194 -0.316365 -0.289724 -0.317990 -0.302061
# 5     -0.673596 -0.637374 -0.688136 -0.554702 -0.615518 -0.621601 -0.662107
#
#              7         8         9   ...        14        15        16  \
# group                                ...
# 0     -0.314537 -0.278030 -0.237940  ... -0.278515 -0.241501 -0.254221
# 1     -0.411491 -0.402062 -0.375112  ... -0.399200 -0.388261 -0.350233
# 2     -0.512049 -0.488323 -0.448694  ... -0.478996 -0.440186 -0.457648
# 3     -0.266239 -0.283915 -0.256179  ... -0.270057 -0.271994 -0.220824
# 4     -0.320983 -0.328372 -0.281335  ... -0.316324 -0.292809 -0.293192
# 5     -0.703635 -0.646415 -0.605018  ... -0.634393 -0.561759 -0.668578
#
#              17        18        19        20        21        22        23
# group
# 0     -0.253755 -0.271725 -0.241569 -0.311300 -0.240135 -0.316325 -0.240863
# 1     -0.398449 -0.396745 -0.377139 -0.439627 -0.367280 -0.440942 -0.372244
# 2     -0.442924 -0.466567 -0.406651 -0.542172 -0.460785 -0.539057 -0.446942
# 3     -0.314046 -0.313420 -0.275384 -0.279889 -0.232030 -0.282589 -0.222499
# 4     -0.331887 -0.348964 -0.291988 -0.325997 -0.274268 -0.320995 -0.249856
# 5     -0.609868 -0.672498 -0.585503 -0.695342 -0.611478 -0.667997 -0.524675
#
# [6 rows x 24 columns]

# %% [markdown]
# ### Distances

# %%
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.62226322, 1.00013029, 0.17643762, 0.22454543, 1.78447219,
#        0.39941874, 0.61551193, 0.44610012, 1.18651136, 1.00736562,
#        0.82471414, 0.79783581, 0.20179974, 1.78430212, 1.59782333])

# %%
distances.max()
# Out:
# 1.784472190907171

# %%
distances.min()
# Out:
# 0.17643761529066868

# %%
tempoA=X.reshape(X.shape[1],-1).T
print(tempoA.shape)
# Out:
# (4320, 51)

# %% [markdown]
# ### Distance groups training

# %%
#Distance between the features in the two groups of the treining
means=temptr.groupby('group').mean()
from scipy.spatial.distance import pdist, squareform

distances = pdist(means, metric='euclidean')
distances
# Out:
# array([0.62226322, 1.00013029, 0.17643762, 0.22454543, 1.78447219,
#        0.39941874, 0.61551193, 0.44610012, 1.18651136, 1.00736562,
#        0.82471414, 0.79783581, 0.20179974, 1.78430212, 1.59782333])

# %%
distances.max()
# Out:
# 1.784472190907171

# %%
distances.min()
# Out:
# 0.17643761529066868

# %%
#media total training
meanTr=tempoA.mean(axis=0)
meanTr.shape
# Out:
# (51,)

# %%
tempoB=pd.DataFrame(tempoA)
from itertools import cycle
variables= cycle(yo)
print(variables)
tempoB['group'] = [next(variables) for variable in range(len(tempoB))]
#Bboxplot  of features by class
a=tempoB.groupby('group').mean()
# Out:
# <itertools.cycle object at 0x00000211225B8400>

# %%
ts1=a.iloc[5,:]
from statsmodels.tsa.stattools import adfuller
result = adfuller(ts1)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.451374
# p-value: 0.000000
# Critical Values:
# 	1%: -3.571
# 	5%: -2.923
# 	10%: -2.599

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20,10))
ejex=np.arange(0,51,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-NATOPS training dataset",fontsize=16)
ax.plot(ejex, a.iloc[0,ejex], color='black',lw=5,  label='G1')
ax.plot(ejex, a.iloc[1,ejex], color='cyan', lw=5, label='G2')
ax.plot(ejex, a.iloc[2,ejex], color='blue', lw=5, label='G3')
ax.plot(ejex, a.iloc[3,ejex], color='green', lw=5, label='G4')
ax.plot(ejex, a.iloc[4,ejex], color='red', lw=5,  label='G5')
ax.plot(ejex, a.iloc[5,ejex], color='magenta', lw=5, label='G6')
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import  mutual_info_classif, SelectPercentile, f_classif
ym=tempoB['group']
Xm=tempoB.iloc[:,0:51]
scores1 = mutual_info_classif(Xm,ym)
#scores /= scores.max()
importance1=[i for i,v in enumerate(scores1) if v > .01]
len(importance1)*100/51
# Out:
# 47.05882352941177

# %%
selector = SelectPercentile(f_classif, percentile=30)
Xm_new=selector.fit_transform(Xm, ym)
scores = -np.log10(selector.pvalues_)
#scores /= scores.max()
#print(scores)
#crtucal p-value=.10
importance=[i for i,v in enumerate(scores) if v > 1]
len(importance)*100/51
# Out:
# 100.0

# %% [markdown]
# ### Testing data

# %%
# loading Testing data
Xt, yt = load_data("NATOPS",split="Test")
# Out:
#  Shape of X =  (180, 24, 51)
#  Shape of y =  (180,)
#  New shape of X =  (180, 51, 24)
#  New shape of y =  (180, 6)

# %%
#class size in testing
import numpy as np
np.sum(yt,axis=0)
# Out:
# array([30, 30, 30, 30, 30, 30])

# %%
#Computing random guessing
ar=np.sum(yt,axis=0)
np.max(ar/Xt.shape[0])
# Out:
# 0.16666666666666666

# %%
yto=np.argmax(yt,axis=1)
yto=np.array(yto,dtype=int)
#print(yto)

# %%
#Boxplot of features in the testing dataset
tempote=Xt.reshape(Xt.shape[2],-1).T
tempodfte=pd.DataFrame(tempote)
print(tempodfte.shape)
pyplot.boxplot(tempodfte)
pyplot.show()
# Out:
# (9180, 24)

# %%
#Boxplors of features in each group of the testing dataset
tempte=pd.DataFrame(tempote)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempte['group'] = [next(variables) for variable in range(len(tempte))]
#Boxplot  of features by class in testing
tempte.boxplot(by='group')
# Out:
# <itertools.cycle object at 0x0000021133873400>
# array([[<Axes: title={'center': '0'}, xlabel='[group]'>,
#         <Axes: title={'center': '1'}, xlabel='[group]'>,
#         <Axes: title={'center': '2'}, xlabel='[group]'>,
#         <Axes: title={'center': '3'}, xlabel='[group]'>,
#         <Axes: title={'center': '4'}, xlabel='[group]'>],
#        [<Axes: title={'center': '5'}, xlabel='[group]'>,
#         <Axes: title={'center': '6'}, xlabel='[group]'>,
#         <Axes: title={'center': '7'}, xlabel='[group]'>,
#         <Axes: title={'center': '8'}, xlabel='[group]'>,
#         <Axes: title={'center': '9'}, xlabel='[group]'>],
#        [<Axes: title={'center': '10'}, xlabel='[group]'>,
#         <Axes: title={'center': '11'}, xlabel='[group]'>,
#         <Axes: title={'center': '12'}, xlabel='[group]'>,
#         <Axes: title={'center': '13'}, xlabel='[group]'>,
#         <Axes: title={'center': '14'}, xlabel='[group]'>],
#        [<Axes: title={'center': '15'}, xlabel='[group]'>,
#         <Axes: title={'center': '16'}, xlabel='[group]'>,
#         <Axes: title={'center': '17'}, xlabel='[group]'>,
#         <Axes: title={'center': '18'}, xlabel='[group]'>,
#         <Axes: title={'center': '19'}, xlabel='[group]'>],
#        [<Axes: title={'center': '20'}, xlabel='[group]'>,
#         <Axes: title={'center': '21'}, xlabel='[group]'>,
#         <Axes: title={'center': '22'}, xlabel='[group]'>,
#         <Axes: title={'center': '23'}, xlabel='[group]'>, <Axes: >]],
#       dtype=object)

# %%
tempoA1=Xt.reshape(Xt.shape[1],-1).T
print(tempoA1.shape)
# Out:
# (4320, 51)

# %%
tempoB1=pd.DataFrame(tempoA1)
from itertools import cycle
variables= cycle(yto)
print(variables)
tempoB1['group'] = [next(variables) for variable in range(len(tempoB1))]
#Bboxplot  of features by class
a1=tempoB1.groupby('group').mean()
# Out:
# <itertools.cycle object at 0x00000211236402C0>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(2,figsize=(20,10))
ejex=np.arange(0,51,1)
fig.suptitle("Fig. Plot of mean values of all time series by group-NATOPS trainng (above) and testing(below) dataset",fontsize=16)
ax1.plot(ejex, a.iloc[0,ejex], color='black',lw=3,  label='G1')
ax1.plot(ejex, a.iloc[1,ejex], color='cyan', lw=3, label='G2')
ax1.plot(ejex, a.iloc[2,ejex], color='blue', lw=3, label='G3')
ax1.plot(ejex, a.iloc[3,ejex], color='green', lw=3, label='G4')
ax1.plot(ejex, a.iloc[4,ejex], color='red', lw=3,  label='G5')
ax1.plot(ejex, a.iloc[5,ejex], color='magenta', lw=3, label='G6')
ax1.legend(loc='best', frameon=False)
ax2.plot(ejex, a1.iloc[0,ejex], color='black',lw=3,  label='G1')
ax2.plot(ejex,a1.iloc[1,ejex], color='cyan', lw=3, label='G2')
ax2.plot(ejex, a1.iloc[2,ejex], color='blue', lw=3, label='G3')
ax2.plot(ejex, a1.iloc[3,ejex], color='green', lw=3, label='G4')
ax2.plot(ejex, a1.iloc[4,ejex], color='red', lw=3, label='G5')
ax2.plot(ejex, a1.iloc[5,ejex], color='magenta', lw=3, label='G6')
ax2.legend(loc='best', frameon=False)
plt.show()

# %%
import numpy as np
Xb= np.concatenate((X, Xt),axis=0)
print(Xb.shape)
# Out:
# (360, 51, 24)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
tempo=X.reshape(X.shape[2],-1).T
#print(tempo.shape)
X = scaler.fit_transform(X.reshape(X.shape[2], -1)).reshape(X.shape)
Xb = scaler.fit_transform(Xb.reshape(Xb.shape[2], -1)).reshape(Xb.shape)
Xt = scaler.fit_transform(Xt.reshape(Xt.shape[2], -1)).reshape(Xt.shape)
X1 = scaler.fit_transform(tempo)
#print(X)
tempodf=pd.DataFrame(X1)
print(tempodf.shape)
pyplot.boxplot(tempodf)
pyplot.show()
# Out:
# (9180, 24)

# %%
#media total testung
meanTe=tempoA1.mean(axis=0)
meanTe.shape
# Out:
# (51,)

# %% [markdown]
# ### Distance Training and Testsing

# %%
#Distance Training and Testsing
from scipy.spatial import distance
dst = distance.euclidean(meanTr, meanTe)
dst
# Out:
# 0.3111657523517633

# %% [markdown]
# ### Stationarity

# %%
#Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
Xest = tempoB.iloc[150,0:1751]
result = adfuller(Xest)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 1.050012
# p-value: 0.994767
# Critical Values:
# 	1%: -3.571
# 	5%: -2.923
# 	10%: -2.599

# %%
sm.graphics.tsa.plot_acf(Xest, alpha=.05)
